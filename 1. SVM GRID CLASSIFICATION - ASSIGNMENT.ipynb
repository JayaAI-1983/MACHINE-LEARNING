# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset
# Out:
#            age         bp sg  al  su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c   3   0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c   2   0  normal    normal  notpresent
# 2     4.000000  76.459948  a   1   0  normal    normal  notpresent
# 3     5.000000  76.459948  d   1   0  normal    normal  notpresent
# 4     5.000000  50.000000  c   0   0  normal    normal  notpresent
# ..         ...        ... ..  ..  ..     ...       ...         ...
# 394  51.492308  70.000000  a   0   0  normal    normal  notpresent
# 395  51.492308  70.000000  c   0   2  normal    normal  notpresent
# 396  51.492308  70.000000  c   3   0  normal    normal  notpresent
# 397  51.492308  90.000000  a   0   0  normal    normal  notpresent
# 398  51.492308  80.000000  a   0   0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#            age         bp  al  su         bgr          bu        sc  \
# 0     2.000000  76.459948   3   0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948   2   0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948   1   0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948   1   0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000   0   0  148.112676   25.000000  0.600000
# ..         ...        ...  ..  ..         ...         ...       ...
# 394  51.492308  70.000000   0   0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000   0   2  220.000000   68.000000  2.800000
# 396  51.492308  70.000000   3   0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000   0   0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000   0   0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
dataset["classification_yes"].value_counts()
# Out:
# classification_yes
# True     249
# False    150
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
indep=dataset[["age",'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset["classification_yes"]

# %%
indep.shape
# Out:
# (399, 27)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
param_grid = {
    'kernel': ['poly'],
    'gamma': ['auto'],
    'C': [1,10, 100]
}
grid = GridSearchCV(SVC(probability=True),param_grid,refit=True,verbose=3,n_jobs=-1,cv=3,scoring='f1_weighted')
grid.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# GridSearchCV(cv=3, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [1, 10, 100], 'gamma': ['auto'],
#                          'kernel': ['poly']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,grid_predictions)

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(Y_test,grid_predictions,average='weighted')
print("The F1 macro value for the best parameter{}:\n".format(grid.best_params_),f1_macro)
print("The Confusion matrix:\n",cm)
print("The report:\n",clf_report)
# Out:
# The F1 macro value for the best parameter{'C': 10, 'gamma': 'auto', 'kernel': 'poly'}:
#  1.0
# The Confusion matrix:
#  [[51  0]
#  [ 0 82]]
# The report:
#                precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        51
#         True       1.00      1.00      1.00        82
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 1.0

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.008235      0.003519         0.003067        0.001394        1
# 1       0.011182      0.001216         0.004466        0.003205       10
# 2       0.008090      0.003190         0.001385        0.000981      100
#
#   param_gamma param_kernel                                         params  \
# 0        auto         poly    {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 1        auto         poly   {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 2        auto         poly  {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}
#
#    split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0           0.988727           0.966182           0.977121         0.977343
# 1           1.000000           0.988727           0.977273         0.988667
# 2           0.977654           0.977528           0.977273         0.977485
#
#    std_test_score  rank_test_score
# ...

# %%
age_input=float(input("Age:"))
bp=float(input("bp:"))
al=input("AL:")
su=float(input("SU:"))
bgr=float(input("BGR:"))
bu=float(input("BU:"))
sc=float(input("SC:"))
sod=float(input("SODIUM:"))
pot=float(input("POTASSIUM:"))
hrmo=float(input("HRMO:"))
pcv=float(input("PCV:"))
wc=float(input("WC:"))
rc=float(input("RC:"))
sg_b=float(input("SG_B:"))
sg_c=float(input("SG_C:"))
sg_d=float(input("SG_D:"))
sg_e=float(input("SG_E:"))
rbcnormal=float(input("rbc normal:"))
pc_normal=float(input("PC Normal:"))
pcc_present=float(input("PCC_Present:"))
ba_present=float(input("BA_Present:"))
htn_yes=float(input("HTN_Yes:"))
dm_yes=float(input("DM_Yes:"))
cad_yes=float(input("CAD_Yes:"))
appet_yes=float(input("Appet_Yes:"))
pe_yes=float(input("PE_Yes:"))
ane_yes=float(input("Ane_Yes:"))
# Out:
# Age: 45
# bp: 125
# AL: 3
# SU: 4
# BGR: 158
# BU: 68
# SC: 6
# SODIUM: 136
# POTASSIUM: 6
# HRMO: 15
# PCV: 253
# WC: 8536
# RC: 5
# SG_B: 1
# SG_C: 1
# SG_D: 1
# SG_E: 1
# rbc normal: 1
# PC Normal: 1
# PCC_Present: 1
# BA_Present: 1
# HTN_Yes: 1
# DM_Yes: 1
# CAD_Yes: 1
# Appet_Yes: 1
# PE_Yes: 1
# Ane_Yes: 1

# %%
Future_Prediction=grid.predict([[age_input,bp,al,su,bgr,bu,sc,sod,pot,hrmo,pcv,wc,rc,sg_b,sg_c,sg_d,sg_e,rbcnormal,pc_normal,pcc_present,ba_present,htn_yes,dm_yes,cad_yes,appet_yes,pe_yes,ane_yes]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[False]

# %%
import pickle

# Assuming your scaler is named `scaler`
filename = "final_model_scaler.sav"
pickle.dump(scaler, open(filename, 'wb'))

# %%
# Save the best estimator (SVM model)
model_filename = "final_model_svm.sav"
pickle.dump(grid.best_estimator_, open(model_filename, 'wb'))
