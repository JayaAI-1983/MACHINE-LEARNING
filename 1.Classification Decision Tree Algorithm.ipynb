# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Social_Network_Ads_400.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15985772    Male   55            22228          1
# 1    15305711  Female   23            75027          1
# 2    15435829    Male   27            61783          1
# 3    15117952    Male   54            29226          0
# 4    15963395    Male   31            92493          0
# ..        ...     ...  ...              ...        ...
# 395  15802795    Male   32            57344          0
# 396  15418001    Male   29           149941          0
# 397  15449129    Male   27           107810          0
# 398  15063418    Male   29            51564          0
# 399  15429952    Male   34            20393          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15985772   55            22228          1         True
# 1    15305711   23            75027          1        False
# 2    15435829   27            61783          1         True
# 3    15117952   54            29226          0         True
# 4    15963395   31            92493          0         True
# ..        ...  ...              ...        ...          ...
# 395  15802795   32            57344          0         True
# 396  15418001   29           149941          0         True
# 397  15449129   27           107810          0         True
# 398  15063418   29            51564          0         True
# 399  15429952   34            20393          1         True
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     55            22228          1         True
# 1     23            75027          1        False
# 2     27            61783          1         True
# 3     54            29226          0         True
# 4     31            92493          0         True
# ..   ...              ...        ...          ...
# 395   32            57344          0         True
# 396   29           149941          0         True
# 397   27           107810          0         True
# 398   29            51564          0         True
# 399   34            20393          1         True
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    276
# 1    124
# Name: count, dtype: int64

# %%
indep=dataset[["Age","EstimatedSalary","Gender_Male"]]
dep=dataset["Purchased"]

# %%
indep.shape
# Out:
# (400, 3)

# %%
dep.shape
# Out:
# (400,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion='entropy',random_state=0)
classifier.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
Y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,Y_pred)

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(Y_test,Y_pred)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.76      0.76        93
#            1       0.44      0.41      0.42        41
#
#     accuracy                           0.66       134
#    macro avg       0.59      0.59      0.59       134
# weighted avg       0.65      0.66      0.65       134

# %%
print(cm)
# Out:
# [[71 22]
#  [24 17]]

# %%
classifier.predict([[40,300,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
